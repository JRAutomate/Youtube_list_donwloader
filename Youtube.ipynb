# %%
conda install -c conda-forge pytube
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Jonathan\anaconda3
#
#   added / updated specs:
#     - pytube
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     conda-23.3.1               |   py39haa95532_0         972 KB
#     jsonpatch-1.32             |     pyhd8ed1ab_0          14 KB  conda-forge
#     jsonpointer-2.0            |             py_0           9 KB  conda-forge
#     openssl-1.1.1t             |       h2bbff1b_0         5.5 MB
#     pytube-12.1.3              |     pyhd8ed1ab_0          50 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         6.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   boltons            conda-forge/noarch::boltons-23.0.0-pyhd8ed1ab_0
#   jsonpatch          conda-forge/noarch::jsonpatch-1.32-pyhd8ed1ab_0
#   jsonpointer        conda-forge/noarch::jsonpointer-2.0-py_0
#   pytube             conda-forge/noarch::pytube-12.1.3-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   conda                               23.1.0-py39haa95532_0 --> 23.3.1-py39haa95532_0
#   openssl                                 1.1.1s-h2bbff1b_0 --> 1.1.1t-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# jsonpointer-2.0      | 9 KB      |            |   0%
#
# conda-23.3.1         | 972 KB    |            |   0%
#
#
# openssl-1.1.1t       | 5.5 MB    |            |   0%
#
#
#
# boltons-23.0.0       | 296 KB    |            |   0%
#
#
#
#
# jsonpatch-1.32       | 14 KB     |            |   0%
#
#
#
#
#
# pytube-12.1.3        | 50 KB     |            |   0%
#
#
# openssl-1.1.1t       | 5.5 MB    |            |   0%
#
# conda-23.3.1         | 972 KB    | 1          |   2%
#
#
#
# boltons-23.0.0       | 296 KB    | 5          |   5%
# jsonpointer-2.0      | 9 KB      | ########## | 100%
#
#
#
#
# jsonpatch-1.32       | 14 KB     | ########## | 100%
# jsonpointer-2.0      | 9 KB      | ########## | 100%
#
#
#
#
# jsonpatch-1.32       | 14 KB     | ########## | 100%
#
#
#
# boltons-23.0.0       | 296 KB    | ###2       |  32%
#
#
# openssl-1.1.1t       | 5.5 MB    | 3          |   4%
#
# conda-23.3.1         | 972 KB    | #6         |  16%
#
#
#
# boltons-23.0.0       | 296 KB    | #########1 |  92%
#
#
# openssl-1.1.1t       | 5.5 MB    | 8          |   9%
#
# conda-23.3.1         | 972 KB    | ###7       |  38%
#
#
#
#
#
# pytube-12.1.3        | 50 KB     | ###1       |  32%
#
#
# openssl-1.1.1t       | 5.5 MB    | #2         |  12%
#
# conda-23.3.1         | 972 KB    | ######2    |  63%
#
#
#
#
#
# pytube-12.1.3        | 50 KB     | ########## | 100%
#
#
#
#
#
# pytube-12.1.3        | 50 KB     | ########## | 100%
#
#
#
# boltons-23.0.0       | 296 KB    | ########## | 100%
#
# conda-23.3.1         | 972 KB    | ########7  |  87%
#
#
# openssl-1.1.1t       | 5.5 MB    | #6         |  17%
#
#
# openssl-1.1.1t       | 5.5 MB    | ##3        |  23%
#
#
# openssl-1.1.1t       | 5.5 MB    | ##9        |  29%
#
#
# openssl-1.1.1t       | 5.5 MB    | ###5       |  35%
#
#
# openssl-1.1.1t       | 5.5 MB    | ####1      |  42%
#
#
# openssl-1.1.1t       | 5.5 MB    | ####9      |  50%
#
#
# openssl-1.1.1t       | 5.5 MB    | #####7     |  57%
#
# conda-23.3.1         | 972 KB    | ########## | 100%
#
#
# openssl-1.1.1t       | 5.5 MB    | ######6    |  66%
#
#
# openssl-1.1.1t       | 5.5 MB    | #######3   |  74%
#
#
# openssl-1.1.1t       | 5.5 MB    | ########3  |  84%
#
#
# openssl-1.1.1t       | 5.5 MB    | #########2 |  92%
#
#
# openssl-1.1.1t       | 5.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge mutagen
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Jonathan\anaconda3
#
#   added / updated specs:
#     - mutagen
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mutagen-1.46.0             |     pyhd8ed1ab_0         131 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         131 KB
#
# The following NEW packages will be INSTALLED:
#
#   mutagen            conda-forge/noarch::mutagen-1.46.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# mutagen-1.46.0       | 131 KB    |            |   0%
# mutagen-1.46.0       | 131 KB    | #2         |  12%
# mutagen-1.46.0       | 131 KB    | ########## | 100%
# mutagen-1.46.0       | 131 KB    | ########## | 100%
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge moviepy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Jonathan\anaconda3
#
#   added / updated specs:
#     - moviepy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ffmpeg-4.3.1               |       ha925a31_0        26.2 MB  conda-forge
#     imageio-ffmpeg-0.4.8       |     pyhd8ed1ab_0          20 KB  conda-forge
#     moviepy-1.0.3              |     pyhd8ed1ab_1          78 KB  conda-forge
#     proglog-0.1.9              |             py_0           9 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        26.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   ffmpeg             conda-forge/win-64::ffmpeg-4.3.1-ha925a31_0
#   imageio-ffmpeg     conda-forge/noarch::imageio-ffmpeg-0.4.8-pyhd8ed1ab_0
#   moviepy            conda-forge/noarch::moviepy-1.0.3-pyhd8ed1ab_1
#   proglog            conda-forge/noarch::proglog-0.1.9-py_0
#
#
#
# Downloading and Extracting Packages
#
# proglog-0.1.9        | 9 KB      |            |   0%
#
# imageio-ffmpeg-0.4.8 | 20 KB     |            |   0%
#
#
# ffmpeg-4.3.1         | 26.2 MB   |            |   0%
#
#
#
# moviepy-1.0.3        | 78 KB     |            |   0%
#
#
#
# moviepy-1.0.3        | 78 KB     | ##         |  20%
#
#
# ffmpeg-4.3.1         | 26.2 MB   |            |   0%
# proglog-0.1.9        | 9 KB      | ########## | 100%
# proglog-0.1.9        | 9 KB      | ########## | 100%
#
# imageio-ffmpeg-0.4.8 | 20 KB     | ########   |  81%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | 1          |   1%
#
# imageio-ffmpeg-0.4.8 | 20 KB     | ########## | 100%
#
#
#
# moviepy-1.0.3        | 78 KB     | ########## | 100%
#
#
#
# moviepy-1.0.3        | 78 KB     | ########## | 100%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | 2          |   3%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | 5          |   6%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | 7          |   8%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | 9          |  10%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #1         |  12%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #4         |  15%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #6         |  17%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #8         |  19%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ##         |  21%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ##2        |  23%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ##5        |  25%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ##6        |  27%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ##9        |  30%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ###1       |  32%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ###4       |  34%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ###6       |  36%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ###8       |  38%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ####       |  40%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ####2      |  43%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ####4      |  45%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ####6      |  47%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ####9      |  50%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #####1     |  52%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #####3     |  54%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #####5     |  56%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #####8     |  58%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ######     |  60%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ######2    |  62%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ######4    |  64%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ######6    |  66%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ######8    |  68%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #######    |  71%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #######2   |  73%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #######4   |  75%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #######7   |  77%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #######9   |  79%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########1  |  81%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########3  |  83%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########5  |  85%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########7  |  87%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########9  |  89%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #########1 |  92%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #########3 |  94%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #########5 |  96%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | #########7 |  98%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########## | 100%
#
#
# ffmpeg-4.3.1         | 26.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
from mutagen.mp3 import MP3  
from mutagen.easymp4 import EasyMP4
import mutagen
from mutagen.id3 import ID3, TIT2, TIT3, TALB, TPE1, TRCK, TYER 
from mutagen.mp4 import MP4
from mutagen.easyid3 import EasyID3
import os
import pandas as pd
try:
    import pytube as pt
except:
    print("not possible to import")
def get_songs_Youtube(Location_music,playlist_Youtube):
    playlist_urls=pt.Playlist(playlist_Youtube)
    playlist_old=pd.read_csv(Location_music+'\\'+'Urls_My_Music.csv', sep=',')
    new_songs=[url for url in playlist_urls if  url not in playlist_old['URL'].to_list()]
    for url in new_songs:
        yt=pt.YouTube(url)
        t=yt.streams.filter(only_audio=True).first()
        out_file=t.download(output_path=Location_music+'\\')
        base, ext = os.path.splitext(out_file)
        try:
            title=base.split('-')[1].split(' (')[0]
            artist=base.split('-')[0].replace(Location_music+'\\','')
            MP4_file=EasyMP4(out_file)
            MP4_file["title"]=title
            MP4_file["artist"]=artist
            MP4_file.save()
        except IndexError:
            title=base.replace(Location_music+'\\','')
            artist=base.replace(Location_music+'\\','')
        except:
            continue
        playlist_old=pd.concat([playlist_old, pd.DataFrame.from_records([{'URL':url,'Name':title,'Artist':artist}])])
        print("The song {0} of {1} has been added".format(title,artist))
    playlist_old.to_csv(Location_music+'\\'+'Urls_My_Music.csv',header=True,index=False)

# %%
Music_folder='D:\\Users\Jonathan\Music\Playlist_My_music'
my_playlist='https://www.youtube.com/playlist?list=PLtBFGcNa1-9i8A6YpNXuHfZ4M1yfTYsER'
un_verano_sin_ti='https://www.youtube.com/watch?v=wAjHQXrIj9o&list=PLRW7iEDD9RDStpKHAckdbGs3xaCChAL7Z'
get_songs_Youtube(Music_folder,un_verano_sin_ti)

# %%
from moviepy.editor import *
for file_mp4 in os.listdir(Music_folder):
    if '.mp4' in file_mp4:
        base, ext=os.path.splitext(file_mp4)
        mp3_file=base+'.mp3'
        os.rename(file_mp4,mp3_file)
        mp3_song=MP3(mp3_file)
        try:
            title=base.split('-')[1].split(' (')[0]
            artist=base.split('-')[0].replace(Location_music+'\\','')
        except IndexError:
            title='u'+base.replace(Location_music+'\\','')
            artist='u'+base.replace(Location_music+'\\','')
        mp3_song["title"]=title
        mp3_song["artist"]=artist
        mp3_song.save()

# %%
playlist_old=pd.read_csv(Music_folder+'\\'+'Urls_My_Music.csv', sep=',')

# %%
playlist_old['URL'][0]
# Out:
# 'https://www.youtube.com/watch?v=QyY5EtJsVhE'
